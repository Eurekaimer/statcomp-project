# %% [markdown]
# # Environment Check
#
# This notebook documents the R environment used by the project. It is not required for the command-line workflow, but it provides a convenient interactive check before running the experiments.

# %%
if (!dir.exists("R") && dir.exists("../R")) setwd("..")
stopifnot(dir.exists("R"), dir.exists("scripts"))
if (file.exists("renv/activate.R")) source("renv/activate.R")
source("R/load_project.R")
load_project()

# %%
sessionInfo()

# %%
if (requireNamespace("renv", quietly = TRUE)) renv::status()
