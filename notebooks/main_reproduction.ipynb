# %% [markdown]
# # Main Reproduction Workflow
#
# This notebook is an interactive entry point for reproducing the main experiments. The authoritative batch workflow remains `run_all.R`.

# %%
if (!dir.exists("R") && dir.exists("../R")) setwd("..")
stopifnot(dir.exists("R"), dir.exists("scripts"))
if (file.exists("renv/activate.R")) source("renv/activate.R")
source("R/load_project.R")
load_project()

# %% [markdown]
# ## Smoke Test
#
# Run the smallest executable workflow first.

# %%
source("scripts/smoke_test.R")

# %% [markdown]
# ## Full Pipeline
#
# The command below runs the main experiments. It may take longer than the smoke test.

# %%
source("run_all.R")

# %% [markdown]
# ## Plotting
#
# Combined figures are generated from CSV files by `scripts/plot_results.py`. Run it from a terminal after the main result tables are available:
#
# ```powershell
# python scripts/plot_results.py
# ```
